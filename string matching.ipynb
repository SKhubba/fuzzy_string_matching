# %%
import pandas as pd

import numpy as np

from fuzzywuzzy import fuzz

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix

import re

import string

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Summary: Achieved high accuracy levels (>0.99) through pre-processing,
#          feature creation, and a Random Forest model with minimal tuning.
#
# Future work: Minimize classification error rate using machine learning
#              techniques and existing feature set.

# %% [markdown]
# ## Pre-processing

# %%
# Read in the data

train = pd.DataFrame.from_csv('train.csv')

test = pd.DataFrame.from_csv('test.csv')

# Reset index 

train = train.reset_index(drop=True)

test = test.reset_index(drop=True)
# Out:
# 0.39554185439886175

# %%
# Balance check: ~ 0.40 of train cases match, similar proportion in test df

sum(train['x_id'] == train['y_id'])/len(train)
# Out:
# 0.39582592197320055

# %%
sum(test['x_id'] == test['y_id'])/len(test)
# Out:
# 0.39554185439886175

# %%
# Check for null values: none found

train.isnull().sum()
# Out:
# x_description    0
# x_id             0
# y_description    0
# y_id             0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# x_description    0
# x_id             0
# y_description    0
# y_id             0
# dtype: int64

# %%
# Split into feature set and response

x_train = train[['x_description', 'y_description']]

x_test = test[['x_description', 'y_description']]

y_train = train['x_id'] == train['y_id']

y_test = test['x_id'] == test['y_id']

# Convert training sets to lowercase and remove punctuation

def tidy(text):
    text = text.lower()
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ')
    return(text)

x_train = x_train.applymap(tidy)

x_test = x_test.applymap(tidy)

# Remove commonly used terms (with regex), extra spaces
word_list = ['(^| )inc($| )','(^| )incorporated($| )', '(^| )fund($| )', '(^| )fd($| )', 
             '(^| )ltd($| )', '(^| )limited($| )', '(^| )corporation($| )', '(^| )corp($| )', \
             '(^| )holdings($| )', '(^| )trust($| )', '(^| )company($| )', '(^| )co($| )', \
             '(^| )international($| )', '(^| )the($| )',  '(^| )class($| )',  '(^| )cl($| )', \
             '(^| )international($| )']

def remove_words(text, word_list):
    words = '|'.join(word_list)
    text = re.sub(words, ' ', text)
    text = re.sub('  ', ' ', text)
    text = re.sub('(^ | $)', '', text)
    return(text)
    
x_train = x_train.applymap(lambda x: remove_words(x, word_list))

x_test = x_test.applymap(lambda x: remove_words(x, word_list))

# %% [markdown]
# ## Feature Creation

# %%
# Absolute value of the difference in the number of space-delimited terms of x,y

x_train['num_words'] = x_train.apply(lambda row: abs(len(str.split(row['x_description'])) - \
      len(str.split(row['y_description']))), axis = 1)

x_test['num_words'] = x_test.apply(lambda row: abs(len(str.split(row['x_description'])) - \
      len(str.split(row['y_description']))), axis = 1)

# Dummy variable for: does the first term match perfectly?

x_train['first_match'] = np.array(x_train.apply(lambda row: re.search('^[^\s]+', \
       row['x_description']).group() == re.search('^[^\s]+', row['y_description']).group(), \
       axis = 1), dtype = 'int')

x_test['first_match'] = np.array(x_test.apply(lambda row: re.search('^[^\s]+', \
      row['x_description']).group() == re.search('^[^\s]+', row['y_description']).group(), \
      axis = 1), dtype = 'int')

# %% [markdown]
# ### Feature Creation Using fuzzywuzzy package

# %%
# Partial ratio

x_train['partial'] = x_train.apply(lambda row: fuzz.partial_ratio(row['x_description'], \
       row['y_description']), axis = 1)

x_test['partial'] = x_test.apply(lambda row: fuzz.partial_ratio(row['x_description'], \
      row['y_description']), axis = 1)

# Partial token set ratio

x_train['ptsr'] = x_train.apply(lambda row: fuzz.partial_token_set_ratio(row['x_description'], \
       row['y_description']), axis = 1)

x_test['ptsr'] = x_test.apply(lambda row: fuzz.partial_token_set_ratio(row['x_description'], \
      row['y_description']), axis = 1)

# Token sort

x_train['token_sort'] = x_train.apply(lambda row: fuzz.token_sort_ratio(row['x_description'], \
       row['y_description']), axis = 1)

x_test['token_sort'] = x_test.apply(lambda row: fuzz.token_sort_ratio(row['x_description'], \
      row['y_description']), axis = 1)

# Token set

x_train['token_set'] = x_train.apply(lambda row: fuzz.token_set_ratio(row['x_description'], \
       row['y_description']), axis = 1)

x_test['token_set'] = x_test.apply(lambda row: fuzz.token_set_ratio(row['x_description'], \
      row['y_description']), axis = 1)

# Ratio

x_train['ratio'] = x_train.apply(lambda row: fuzz.ratio(row['x_description'], \ 
      row['y_description']), axis = 1)

x_test['ratio'] = x_test.apply(lambda row: fuzz.ratio(row['x_description'], \
      row['y_description']), axis = 1)

# Partial ratio for series of first letters in each term

def firstletter(x):
    L = str.split(x)
    newstring = ' '.join([item[:1] for item in L])
    return(newstring)
    
x_train['first_letter'] = x_train.apply(lambda row: \
       fuzz.partial_ratio(firstletter(row['x_description']), firstletter(row['y_description'])), \
       axis = 1)

x_test['first_letter'] = x_test.apply(lambda row: \
      fuzz.partial_ratio(firstletter(row['x_description']), firstletter(row['y_description'])), \
      axis = 1)

# Token set ratio for string with no vowels

def novowels(x):
    return(''.join([l for l in x if l not in ['a','e','i','o','u']]))

x_train['no_vowels'] = x_train.apply(lambda row: fuzz.token_set_ratio(novowels(row['x_description']), \
       novowels(row['y_description'])), axis = 1)

x_test['no_vowels'] = x_test.apply(lambda row: fuzz.token_set_ratio(novowels(row['x_description']), \
      novowels(row['y_description'])), axis = 1)

# Token set ratio for first term

x_train['first_ratio'] = x_train.apply(lambda row: fuzz.token_set_ratio(re.search('^[^\s]+', \
       row['x_description']).group(), re.search('^[^\s]+', row['y_description']).group()), axis = 1)

x_test['first_ratio'] = x_test.apply(lambda row: fuzz.token_set_ratio(re.search('^[^\s]+', \
       row['x_description']).group(), re.search('^[^\s]+', row['y_description']).group()), axis = 1)

# Partial ratio for series of first + last letters in each term

def fl_letter(x):
    L = str.split(x)
    newstring = ' '.join([item[:1]+item[-1:] if len(item) != 1 else item[-1:] for item in L])
    return(newstring)
    
x_train['first_last'] = x_train.apply(lambda row: fuzz.partial_ratio(fl_letter(row['x_description']), \
       fl_letter(row['y_description'])), axis = 1)

x_test['first_last'] = x_test.apply(lambda row: fuzz.partial_ratio(fl_letter(row['x_description']), \
      fl_letter(row['y_description'])), axis = 1)

# %% [markdown]
# ## Modeling

# %%
# Omitting the string descriptions / only using created features

x_train = x_train.iloc[:,2:]

x_test = x_test.iloc[:,2:]

# Fit the model

model = RandomForestClassifier(n_estimators = 400, random_state = 0)

model.fit(x_train, y_train)

# Train score

model.score(x_train, y_train)
# Out:
# 0.9999407091189375

# %% [markdown]
# ## Results

# %%
# Train confusion matrix

confusion_matrix(y_train,model.predict(x_train))
# Out:
# array([[10189,     1],
#        [    0,  6676]], dtype=int64)

# %%
# Test confusion matrix: 43 / 4217 misclassified

confusion_matrix(y_test,model.predict(x_test))
# Out:
# array([[2531,   18],
#        [  25, 1643]], dtype=int64)

# %%
# Shown as a proportion of total cases

confusion_matrix(y_test,model.predict(x_test))/len(y_test)
# Out:
# array([[0.60018971, 0.00426844],
#        [0.00592839, 0.38961347]])

# %%
# Output exceptions for further review

miss = np.ravel(np.where(np.array(y_test != model.predict(x_test))))

miss_feat = test.loc[miss,:]

miss_y = y_test.loc[miss]

miss_df = pd.concat([miss_y, miss_feat], axis = 1)

# %%
# Cases that were misclassified shown below

miss_df=miss_df.rename(columns = {0:'True Class'})

miss_df
# Out:
#       True Class                                      x_description   x_id  \
# 75          True                                 Htfd Intl Sm Co R5  49861
# 219         True                              Cleveland-Cliffs Inc.  42461
# 250         True            A-Power Energy Generation Systems, Ltd.   7537
# 263        False  Pimco Municipal Income Fund II of Beneficial I...  32482
# 285         True  State Street Institutional International Equit...  52230
# 359         True                                WF Fund Admin Class  23394
# 396         True           Wells Fargo Target 2050 Fund Admin Class  40076
# 453        False         Neuberger Berman Global Allocation Fd Cl C  16255
# 472        False  Wells Fargo California Limited Term Tax-Free Fund  16674
# 789         True    Westinghouse Air Brake Technologies Corporation  35369
# 795         True  Merrill Lynch Depositor Inc PPlus Tr Ser RRD-1...  24087
# 887        False       Port Street Institutional Opportunities Fund  41069
# 1134        True                               Paramount Group Inc.  30539
# 1149        True                            Med-Cannabis Pharma Inc  48388
# 1165       False             Gartmore Small Cap Growth Fund Class B  18214
# 1187        True                               Col Gl E & N Rsrc I2  19071
# 1195        True                                    AMR Corporation  32359
# 1280        True      iPath Goldman Sachs GBP/USD Exchange Rate ETN  48948
# 1629       False  John Hancock Funds III International Value Equ...  20722
# 1662        True                               Sibanye Gold Limited   6839
# 1856        True                  Southern Connecticut Bancorp Inc.  20372
# 1870        True                                     Fimm Govt CL I  25365
# 2015        True                       SPDR PORTFOLIO SMALL CAP ETF  20921
# 2034       False              Hartford Total Return Bond Fund Cl R5   7188
# 2035        True                            The Walt Disney Company  39039
# 2504       False             Neuberger Berman High Income Bond Fund  39968
# 2506        True  T. Rowe Price Institutional Mid-Cap Equity Gro...  34722
# 2533       False  Schroder Emerging Markets Multi-Cap Equity Fd ...  19873
# 2626        True                              OneMain Holdings Inc.  18952
# 2911       False                   Invesco Libor Alpha Fund Class A  33422
# 2928       False                   Invesco Value Opportunities Fund  27313
# 2941       False                        American Beacon Lg Cap Gr C   5676
# 2988        True         VelocityShares Daily 2x VIX Short Term ETN  52313
# 3203       False                             iShares MSCI China ETF   4306
# 3219       False   The Gabelli Global Small and Mid Cap Value Trust  19909
# 3256        True                        Southwestern Energy Company   4544
# 3300       False            Goldman Sachs Global Managed Beta Fund6  35338
# 3306       False  Harbor Target Retirement 2040 Fund Investor Class  17842
# 3386        True                                                Maa  29224
# 3853       False           American Century Global Growth Fd - A Cl  30341
# 3945        True  International Game Technology Note 5.50000% 06...  50505
# 4172       False            AQR Style Premia Alternative LV Fund -6  25414
# 4183        True                                LM BW GLB OPP BD IS  48568
#
#                                           y_description   y_id
# 75       The Hartford International Small Company Fund5  49861
# 219                              CLIFFS NAT RES INC COM  42461
# 250     Astropower Inc No Stockholder Equity 12/27/2004   7537
# 263   First Trust MLP and Energy Income Fund of Bene...  20075
# 285                                       GE INT'L FUND  52230
# 359                       Wells Fargo Common Stk Adm CL  23394
# 396                              Vaneck Merk Gold Trust  40076
# 453         Neuberger Berman Large Cap Value Fd Inst Cl  13320
# 472   Wells Fargo Advantage Enterprise Fund Investor...  52342
# 789                                              WABTEC  35369
# 795   20Preferredplus Trust CL a Series Rrd-1 Donnel...  24087
# 887   John Hancock Fds II Strategic Income Opportuni...  39057
# 1134                                               Pgre  30539
# 1149                  Mansfield Martin Expl Mng Inc Com  48388
# 1165                  Franklin Small Cap Growth Fd Cl C  36046
# 1187  Columbia Global Energy and Natural Resources F...  19071
# 1195                             Alta Mesa Res Inc CL A  32359
# 1280  Barclays Bank PLC Ipath ETN Great Britain Poun...  48948
# 1629  John Hancock Funds II Multimanager Lifestyle B...  49251
# 1662  D/B/A Sibanye-Stillwater Limited American Depo...   6839
# 1856               SEVENTY SEVEN ENERGY INC COM USD0.01  20372
# 1870  Fidelity Institutional Money Market Fds: Gov P...  25365
# 2015                                  SPDR Russell 2000  20921
# 2034     The Hartford Municipal Opportunities Fund Cl A  46537
# 2035                               DISNEY STOCK-NONESOP  39039
# 2504         Neuberger Berman Global Allocation Fd Cl C  16255
# 2506                                Trp Inst Mdcpeq Gth  34722
# 2533             Federated Emerging Market Debt Fd Cl C  50004
# 2626                                                Omf  18952
# 2911          Invesco U.S. Small Cap Value Fund Class C  21845
# 2928                   Orinda Income Opportunities Fund   9253
# 2941            American Century All Cap Growth Fd A Cl  31088
# 2988  Credit Suisse Nassau Brh Velocity Shs Shr 0.00...  52313
# 3203          iShares Barclays TIPS Bond ETF 529 Port A  42636
# 3219                        KEELEY Small Cap Value Fund   8139
# 3256                                                Swn   4544
# 3300    Goldman Sachs Local Emerging Markets Debt Fund6  50842
# 3306  American Funds 2030 Target Date Retirement Fd ...  29558
# 3386             Mid-America Apartment Communities Inc.  29224
# 3853        American Century Short Term Government A Cl  43616
# 3945  Intl Game Technology Sr Unsecured Cpn 5.500% D...  50505
# 4172          AC Alternatives Long Short Fund - R Class  37787
# 4183  BrandywineGLOBAL - Global Opportunities Bond F...  48568
